# %%
# use open cv to show new images from AirSim 

import setup_path 
import airsim

# requires Python 3.5.3 :: Anaconda 4.4.0

# pip install opencv-python
import cv2
import time
import math
import sys
import numpy as np

# %%
from PIL import Image

def getScreenDepthVis():

    responses = client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.DepthPerspective, True, False)])
    img1d = np.array(responses[0].image_data_float, dtype=np.float)
    img1d = 255/np.maximum(np.ones(img1d.size), img1d)
    img2d = np.reshape(img1d, (responses[0].height, responses[0].width))

    image = np.invert(np.array(Image.fromarray(img2d.astype(np.uint8), mode='L')))

    factor = 10
    maxIntensity = 255.0 # depends on dtype of image data

    # Decrease intensity such that dark pixels become much darker, bright pixels become slightly dark 
    newImage1 = (maxIntensity)*(image/maxIntensity)**factor
    newImage1 = np.array(newImage1,dtype=np.uint8)

    #cv2.imshow("Test", newImage1)
    #cv2.waitKey(0)

    return newImage1

# %%
import matplotlib.pyplot as plt

# %%
client = airsim.MultirotorClient()
client.confirmConnection()
client.enableApiControl(True)
client.armDisarm(True)
client.takeoffAsync().join()
# client.moveByVelocityAsync(0,0,-5,10)
# client.hoverAsync()
# you must first press "1" in the AirSim view to turn on the depth capture

# get depth image
yaw = 0
pi = 3.14159265483
vx = 0
vy = 0
driving = 0
help = False
# Out:
# Connected!
# Client Ver:1 (Min Req: 1), Server Ver:1 (Min Req: 1)

# %%
from PIL import Image

responses = client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.DepthPerspective, True, False)])
img1d = np.array(responses[0].image_data_float, dtype=np.float)
img1d = 255/np.maximum(np.ones(img1d.size), img1d)
img2d = np.reshape(img1d, (responses[0].height, responses[0].width))
        
image = np.invert(np.array(Image.fromarray(img2d.astype(np.uint8), mode='L')))
        
factor = 10
maxIntensity = 255.0 # depends on dtype of image data
        
        # Decrease intensity such that dark pixels become much darker, bright pixels become slightly dark 
newImage1 = (maxIntensity)*(image/maxIntensity)**factor
newImage1 = np.array(newImage1,dtype=np.uint8)
        
        #cv2.imshow("Test", newImage1)
        #cv2.waitKey(0)
        
#         return newImage1

# %%
fly_speed=10
turn_speed=0.5
while True:
    # this will return png width= 256, height= 144
    result = client.simGetImage("0", airsim.ImageType.DepthVis)
    if (result == "\0"):
        if (not help):
            help = True
            print("Please press '1' in the AirSim view to enable the Depth camera view")
    else:    
#         rawImage = np.fromstring(result, np.int8)
#         print("rawImage is",rawImage)
#         png = cv2.imdecode(rawImage, cv2.IMREAD_UNCHANGED)
#         gray = cv2.cvtColor(png, cv2.COLOR_BGR2GRAY)
        gray = getScreenDepthVis()
        # slice the image so we only check what we are headed into (and not what is down on the ground below us).
        top = np.vstack((np.vsplit(gray, 3)[0],np.vsplit(gray, 3)[1]))
        #top = np.vsplit(gray, 3)[0]

        # now look at 4 horizontal bands (far left, left, right, far right) and see which is most open.
        # the depth map uses black for close (0) and white for far away(255), so we invert that
        # to get an estimate of distance.
        bands = np.hsplit(top, [50,100,150,200]);
        mins = [np.min(x) for x in bands]
        max = np.argmax(mins)    
        distance = mins[max]

        # sanity check on what is directly in front of us (slot 2 in our hsplit)
        current = mins[2]
        print ("max distance=", current)
        print ("distance=", current)
#         if (current <20):
#             client.hoverAsync().join()
#             airsim.wait_key("whoops - we are about to crash, so stopping!")
    
        pitch, roll, yaw  = airsim.to_eularian_angles(client.simGetVehiclePose().orientation)

        if (distance > current + 10):
        
            # we have a 90 degree field of view (pi/2), we've sliced that into 5 chunks, each chunk then represents
            # an angular delta of the following pi/10.
            change = 0
            driving = max
            if (max == 0):
                change = -2 * pi / 10
            elif (max == 1):
                change = -pi / 10
            elif (max == 2):
                change = 0 # center strip, go straight
            elif (max == 3):
                change = pi / 10
            else:
                change = 2*pi/10
    
            yaw = (yaw + change)
            vx = turn_speed*math.cos(yaw);
            vy = turn_speed*math.sin(yaw);
            print ("switching angle", math.degrees(yaw), vx, vy, min, distance, current)
    
        if (vx == 0 and vy == 0):
            vx = math.cos(yaw);
            vy = math.sin(yaw);

        #print ("distance=", current)
        client.moveByVelocityZAsync(fly_speed*vx, fly_speed*vy,-25, 1, airsim.DrivetrainType.ForwardOnly, airsim.YawMode(False, 0)).join()

        x = int(driving * 50)
        cv2.rectangle(gray, (x,0), (x+50,50), (0,255,0), 2)
        cv2.imshow("Top", top)

    key = cv2.waitKey(1) & 0xFF;
    if (key == 27 or key == ord('q') or key == ord('x')):
        break;
# Out:
# max distance= 79
# distance= 79
# max distance= 117
# distance= 117
# max distance= 178
# distance= 178
# switching angle 18.000001069292416 0.4755282552640351 0.15450850606210223 <built-in function min> 200 178
# max distance= 200
# distance= 200
# switching angle -19.191226183270604 0.4722133595843883 -0.1643610143252504 <built-in function min> 226 200
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# max distance= 178
# distance= 178
# switching angle -37.18130964988902 0.3983635503990191 -0.30216962407477055 <built-in function min> 200 178
# max distance= 193
# distance= 193
# max distance= 193
# distance= 193
# max distance= 178
# distance= 178
# switching angle -1.1790985263521303 0.4998941283674638 -0.010288849485421659 <built-in function min> 193 178
# max distance= 178
# distance= 178
# max distance= 164
# distance= 164
# switching angle 34.84704616906605 0.41034015671795054 0.2856938147469906 <built-in function min> 178 164
# max distance= 178
# distance= 178
# max distance= 209
# distance= 209
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# switching angle 16.847173154467466 0.47854060272414284 0.14490994287630538 <built-in function min> 226 200
# max distance= 193
# distance= 193
# switching angle 0.1771760680829336 0.4999976094132017 0.0015461504077498665 <built-in function min> 209 193
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# max distance= 185
# distance= 185
# switching angle -17.822825299156182 0.4760037676643771 -0.15303729339385785 <built-in function min> 200 185
# max distance= 185
# distance= 185
# max distance= 170
# distance= 170
# max distance= 170
# distance= 170
# max distance= 151
# distance= 151
# max distance= 151
# distance= 151
# switching angle 0.17710886813468776 0.49999761122627634 0.001545563980375598 <built-in function min> 209 151
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# switching angle -35.91301921036112 0.4049541896329416 -0.29327820290421786 <built-in function min> 209 193
# max distance= 200
# distance= 200
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# switching angle -53.900386050360204 0.2945954566127192 -0.403996926898143 <built-in function min> 226 193
# max distance= 193
# distance= 193
# switching angle -70.56479199575278 0.16637033765243142 -0.47150918416231935 <built-in function min> 226 193
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# switching angle -106.56112702941752 -0.1425190584485049 -0.4792580911982099 <built-in function min> 226 209
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# max distance= 178
# distance= 178
# max distance= 164
# distance= 164
# switching angle -142.5613610028501 -0.3970024195942432 -0.3039557185451796 <built-in function min> 178 164
# max distance= 157
# distance= 157
# switching angle -122.26391489667441 -0.2669099471401002 -0.4227991013680953 <built-in function min> 178 157
# max distance= 157
# distance= 157
# switching angle -105.49116795733568 -0.133544915490356 -0.4818358180404127 <built-in function min> 185 157
# max distance= 170
# distance= 170
# max distance= 193
# distance= 193
# max distance= 178
# distance= 178
# max distance= 157
# distance= 157
# switching angle -123.49126223879863 -0.2759049045265628 -0.41698499212584167 <built-in function min> 193 157
# max distance= 185
# distance= 185
# max distance= 178
# distance= 178
# max distance= 164
# distance= 164
# max distance= 133
# distance= 133
# switching angle -105.49125766058268 -0.13354566986054497 -0.4818356089596309 <built-in function min> 170 133
# max distance= 144
# distance= 144
# switching angle -88.83081814988985 0.010202328330227111 -0.4998959016601779 <built-in function min> 200 144
# max distance= 193
# distance= 193
# switching angle -54.161954441423354 0.2927480543986776 -0.4053376082302121 <built-in function min> 217 193
# max distance= 209
# distance= 209
# max distance= 193
# distance= 193
# switching angle -36.325593983771675 0.40283187499287954 -0.29618656365493873 <built-in function min> 217 193
# max distance= 200
# distance= 200
# switching angle -19.648852925554436 0.47088554474022676 -0.16812734386381029 <built-in function min> 217 200
# max distance= 209
# distance= 209
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# switching angle 16.344236626797205 0.4797941551186702 0.14070383333072853 <built-in function min> 217 200
# max distance= 185
# distance= 185
# switching angle 50.81726316909739 0.31589789193607437 0.3875674417057556 <built-in function min> 226 185
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# switching angle 14.762707099119165 0.48349472466431714 0.12740820704246703 <built-in function min> 217 200
# max distance= 209
# distance= 209
# max distance= 209
# distance= 209
# switching angle 32.86305900048693 0.4199849487089388 0.2713164994207872 <built-in function min> 226 209
# max distance= 235
# distance= 235
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# switching angle -3.1368405322610426 0.49925084592722396 -0.027360424721690306 <built-in function min> 235 217
# max distance= 235
# distance= 235
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# switching angle -39.13684116250142 0.38782036119193675 -0.31558733726966254 <built-in function min> 226 209
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# switching angle -75.18183461547319 0.1278761361788931 -0.48337117600862095 <built-in function min> 235 217
# max distance= 235
# distance= 235
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# switching angle -111.18281246446962 -0.18067243808717506 -0.4662161195364612 <built-in function min> 235 217
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# switching angle -147.1829971333461 -0.42020290566079627 -0.27097881480703234 <built-in function min> 245 217
# max distance= 226
# distance= 226
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# switching angle -111.18305121164505 -0.18067438077287987 -0.46621536668404273 <built-in function min> 255 235
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 255
# distance= 255
# max distance= 245
# distance= 245
# max distance= 245
# distance= 245
# max distance= 245
# distance= 245
# max distance= 245
# distance= 245
# max distance= 245
# distance= 245
# max distance= 245
# distance= 245

# %%
plt.imshow(newImage1,plt.cm.gray)

# %%
response=client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.DepthPlanner, pixels_as_float=True)])[0]

# %%
depth = np.array(response.image_data_float)
depth = depth.reshape(response.height, response.width)
#depth = np.array(depth * 255, dtype=np.uint8)

# %%
 np.array(response.image_data_float)[160:180]

# %%
result = client.simGetImage("0", airsim.ImageType.Segmentation)

rawImage = np.fromstring(result, np.int8)
png = cv2.imdecode(rawImage, cv2.IMREAD_UNCHANGED)
gray = cv2.cvtColor(png, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(png)

# %%
 np.array(depth * 255, dtype=np.uint8)

# %%
depth = np.array(response.image_data_float)
depth = depth.reshape(response.height, response.width)

# %%
depth [0][160:180]

# %%
plt.imshow(depth,plt.cm.gray)

# %%
img1d = np.fromstring(response.image_data_uint8, dtype=np.uint8)
#img_rgb = img1d.reshape(response.height, response.width, 3) # reshape array to 3 channel image array H X W X 3
cv2.imwrite("./try.png", img1d) # write to png

# %%
img1d = np.fromstring(response.image_data_uint8, dtype=np.uint8) # get numpy array
img_rgb = img1d.reshape(response.height, response.width, 3) # reshape array to 3 channel image array H X W X 3

# %%
len(img1d)

# %%
result_scene =client.simGetImage("0", airsim.ImageType.Scene)
rawImage = np.fromstring(result_scene, np.int8)

# %%
len(rawImage)

# %%
response=(client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.DepthVis)])[0])

# %%
tmp=client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.DepthVis,False, False)])[0].image_data_uint8

# %%
tmp=client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.DepthVis, pixels_as_float=True)])[0]

# %%
rawImage = np.fromstring(tmp, np.int8)

# %%
rawImage = np.frombuffer(tmp, np.int8)

# %%
tmp

# %%
plt.imshow(gray)

# %%
png = cv2.imdecode(rawImage, cv2.IMREAD_UNCHANGED)
gray = cv2.cvtColor(png, cv2.COLOR_BGR2GRAY)

# %%
color = cv2.cvtColor(depth, cv2.COLOR_GRAY2RNG)

# %%
depth[0]

# %%
depth = np.array(response.image_data_float)
depth = depth.reshape(response.height, response.width)
#depth = np.array(depth * 253, dtype=np.uint8)

# %%
depth

# %%
(depth * 255)[0][160:180]

# %%
plt.imshow(depth,)

# %%
response.image_data_float[160:180]

# %%
depth[0]

# %%
depth[0][160:180]

# %%
png = cv2.imdecode(rawImage, cv2.IMREAD_UNCHANGED)

# %%
response.image_data_uint8

# %%
plt.imshow(depth,plt.cm.gray)

# %%
result_scene =client.simGetImage("0", airsim.ImageType.Scene)
rawImage = np.fromstring(result_scene, np.int8)
png = cv2.imdecode(rawImage, cv2.IMREAD_UNCHANGED)

# %%
result =client.simGetImage("4", airsim.ImageType.DepthPlanner)
rawImage = np.fromstring(result, np.int8)
png = cv2.imdecode(rawImage, cv2.IMREAD_UNCHANGED)
gray = cv2.cvtColor(png, cv2.COLOR_BGR2GRAY)

# %%
rawImage=np.int8(np.ones(np.size(rawImage))*0)+rawImage

# %%
np.unique(png)

# %%
rawImage=np.ones(np.size(rawImage))*0+rawImage
png = cv2.imdecode(rawImage, cv2.IMREAD_UNCHANGED)
##gray = cv2.cvtColor(png, cv2.COLOR_BGR2GRAY)

# %%
response=client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.DepthPlanner,False, False)])[0]
img1d = np.fromstring(response.image_data_uint8, dtype=np.uint8) # get numpy array
img_rgb = img1d.reshape(response.height, response.width, 3) # reshape array to 4 channel image array H X W X 3
cv2.imwrite(os.path.normpath(filename + '.png'), img_rgb) # write to png

# %%
cv2.imwrite("./try2.png",response.image_data_uint8)

# %%
fh = open("./try2.png", "wb")
fh.write(response.image_data_uint8)
fh.close()

# %%
png = cv2.imdecode(img1d, cv2.IMREAD_UNCHANGED)

# %%
np.unique(png)

# %%
# call airsim
responses = client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.Scene, True)])
response = responses[0]
# convert to grayscale
depth = np.array(response.image_data_float, dtype=np.float32)
depth = depth.reshape(response.height, response.width)
depth = np.array(depth * 255, dtype=np.uint8)
# save pic
# cv2.imwrite('./depth.png'.format(name_folder, t), depth)

# %%
cv2.imwrite("./filename.png", depth)

# %%
rawImage = np.fromstring(tmp, np.int8)

# %%
result_depth = client.simGetImage("0", airsim.ImageType.DepthVis)
rawImage = np.fromstring(result_depth, np.int8)

# %%
np.size(rawImage)

# %%
result_DepthPlanner = client.simGetImage("0", airsim.ImageType.DepthPlanner)

# %%
# result_DepthPlanner = client.simGetImage("0", airsim.ImageType.DepthPlanner)
result_DepthPlanner=client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.DepthPlanner, pixels_as_float=True)])

# %%
rawImage = np.fromstring(result_DepthPlanner, np.int8)

# %%
result_DisparityNormalized = client.simGetImage("0", airsim.ImageType.DisparityNormalized)
rawImage = np.fromstring(result_DisparityNormalized, np.int8)

# %%
result_Segmentation  = client.simGetImage("0", airsim.ImageType.Segmentation)
rawImage = np.fromstring(result_Segmentation, np.int8)

# %%
rawImage = np.fromstring(result_DepthPlanner, np.int8)

# %%
png = cv2.imdecode(rawImage, cv2.IMREAD_GRAYSCALE)
# gray = cv2.cvtColor(png, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(png)

# %%
# call airsim
responses = client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.DepthVis, True)])
response = responses[0]
# convert to grayscale
depth = np.array(response.image_data_float, dtype=np.float32)
depth = depth.reshape(response.height, response.width)
depth = np.array(depth * 255, dtype=np.uint8)
# save pic
# cv2.imwrite('{}/depth{}.png'.format(self.name_folder, self.t), depth)

# %%
plt.imshow(depth)

# %%
np.size(rawImage)

# %%
np.reshape(rawImage,[2,2389])

# %%
len(rawImage)/2

# %%
plt.imshow(png)

# %%
import numpy as np
import urllib
import cv2

url = 'http://www.pyimagesearch.com/wp-content/uploads/2015/01/google_logo.png'
resp = urllib.urlopen(url)
image = np.asarray(bytearray(resp.read()), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)
cv2.imshow('URL2Image',image)

# %%
plt.imshow(png)

# %%
top = np.vsplit(gray, 3)[0]

# %%
np.vsplit(gray, 2)

# %%
bands = np.hsplit(top, [50,100,150,200]);

# %%
        maxes = [np.max(x) for x in bands]
        min = np.argmin(maxes)    
        distance = 255 - maxes[min]

        # sanity check on what is directly in front of us (slot 2 in our hsplit)
        current = 255 - maxes[2]

# %%
plt.imshow(bands[5])

# %%
gray = getScreenDepthVis()
# slice the image so we only check what we are headed into (and not what is down on the ground below us).

top = np.vsplit(gray, 2)[0]

# now look at 4 horizontal bands (far left, left, right, far right) and see which is most open.
# the depth map uses black for far away (0) and white for very close (255), so we invert that
# to get an estimate of distance.
bands = np.hsplit(top, [50,100,150,200]);
maxes = [np.max(x) for x in bands]
min = np.argmin(maxes)    
distance = 255 - maxes[min]

# sanity check on what is directly in front of us (slot 2 in our hsplit)
current = 255 - maxes[2]

# %%
bands

# %%
plt.imshow(gray,plt.cm.gray)

# %%
fly_speed=10
turn_speed=0.5
while True:
    # this will return png width= 256, height= 144
    result = client.simGetImage("0", airsim.ImageType.DepthVis)
    if (result == "\0"):
        if (not help):
            help = True
            print("Please press '1' in the AirSim view to enable the Depth camera view")
    else:    
#         rawImage = np.fromstring(result, np.int8)
#         print("rawImage is",rawImage)
#         png = cv2.imdecode(rawImage, cv2.IMREAD_UNCHANGED)
#         gray = cv2.cvtColor(png, cv2.COLOR_BGR2GRAY)
        gray = getScreenDepthVis()
        # slice the image so we only check what we are headed into (and not what is down on the ground below us).
        top = np.vstack((np.vsplit(gray, 3)[0],np.vsplit(gray, 3)[1]))
        #top = np.vsplit(gray, 3)[0]

        # now look at 4 horizontal bands (far left, left, right, far right) and see which is most open.
        # the depth map uses black for close (0) and white for far away(255), so we invert that
        # to get an estimate of distance.
        bands = np.hsplit(top, [50,100,150,200]);
        mins = [np.min(x) for x in bands]
        max = np.argmax(mins)    
        distance = mins[max]

        # sanity check on what is directly in front of us (slot 2 in our hsplit)
        current = mins[2]
        print ("max distance=", current)
        print ("distance=", current)
#         if (current <20):
#             client.hoverAsync().join()
#             airsim.wait_key("whoops - we are about to crash, so stopping!")
    
        pitch, roll, yaw  = airsim.to_eularian_angles(client.simGetVehiclePose().orientation)

        if (distance > current + 10):
        
            # we have a 90 degree field of view (pi/2), we've sliced that into 5 chunks, each chunk then represents
            # an angular delta of the following pi/10.
            change = 0
            driving = max
            if (max == 0):
                change = -2 * pi / 10
            elif (max == 1):
                change = -pi / 10
            elif (max == 2):
                change = 0 # center strip, go straight
            elif (max == 3):
                change = pi / 10
            else:
                change = 2*pi/10
    
            yaw = (yaw + change)
            vx = turn_speed*math.cos(yaw);
            vy = turn_speed*math.sin(yaw);
            print ("switching angle", math.degrees(yaw), vx, vy, min, distance, current)
    
        if (vx == 0 and vy == 0):
            vx = math.cos(yaw);
            vy = math.sin(yaw);

        #print ("distance=", current)
        client.moveByVelocityZAsync(fly_speed*vx, fly_speed*vy,-25, 1, airsim.DrivetrainType.ForwardOnly, airsim.YawMode(False, 0)).join()

        x = int(driving * 50)
        cv2.rectangle(gray, (x,0), (x+50,50), (0,255,0), 2)
        cv2.imshow("Top", top)

    key = cv2.waitKey(1) & 0xFF;
    if (key == 27 or key == ord('q') or key == ord('x')):
        break;
# Out:
# max distance= 107
# distance= 107
# switching angle 215.99995903307672 -0.40450870732285976 -0.2938923369194729 <built-in function min> 127 107
# max distance= 107
# distance= 107
# max distance= 185
# distance= 185
# switching angle -107.5013546854304 -0.15036417441890074 -0.47685492033879906 <built-in function min> 209 185
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# max distance= 193
# distance= 193
# max distance= 185
# distance= 185
# max distance= 178
# distance= 178
# max distance= 178
# distance= 178
# max distance= 164
# distance= 164
# max distance= 144
# distance= 144
# switching angle -71.5011122267247 0.1586431237345445 -0.47416490727567134 <built-in function min> 170 144
# max distance= 151
# distance= 151
# switching angle -91.07138983485274 -0.009349095234157 -0.49991258677723116 <built-in function min> 170 151
# max distance= 164
# distance= 164
# max distance= 151
# distance= 151
# max distance= 127
# distance= 127
# max distance= 144
# distance= 144
# switching angle -109.07081585041158 -0.16336826892344977 -0.47255773055676004 <built-in function min> 170 144
# max distance= 170
# distance= 170
# max distance= 157
# distance= 157
# max distance= 170
# distance= 170
# max distance= 151
# distance= 151
# switching angle -127.0703627006168 -0.3013976710287034 -0.39894792128606643 <built-in function min> 170 151
# max distance= 127
# distance= 127
# switching angle -143.92123927819335 -0.40410412035962573 -0.29444839939855866 <built-in function min> 157 127
# max distance= 122
# distance= 122
# switching angle -178.6237602840562 -0.49985576786361213 -0.012008802333235433 <built-in function min> 217 122
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# max distance= 170
# distance= 170
# switching angle -196.6370238416547 -0.47906888301136596 0.1431537821024724 <built-in function min> 217 170
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# max distance= 178
# distance= 178
# switching angle 145.36058521992052 -0.41137277202162204 0.28420493035703404 <built-in function min> 193 178
# max distance= 193
# distance= 193
# max distance= 193
# distance= 193
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# max distance= 178
# distance= 178
# switching angle 181.36045052538694 -0.4998590581899034 -0.011871054944814042 <built-in function min> 200 178
# max distance= 193
# distance= 193
# max distance= 209
# distance= 209
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# switching angle -160.63925737124615 -0.47172501174906684 -0.1657573928678379 <built-in function min> 209 193
# max distance= 209
# distance= 209
# switching angle -143.39058228311086 -0.4013597313818839 -0.298178413076906 <built-in function min> 235 209
# max distance= 226
# distance= 226
# max distance= 209
# distance= 209
# max distance= 209
# distance= 209
# max distance= 235
# distance= 235
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# switching angle -161.39051492828133 -0.47385779733537 -0.1595581019706346 <built-in function min> 235 217
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# max distance= 209
# distance= 209
# switching angle -125.39051035822523 -0.28957307922712544 -0.40761186413906175 <built-in function min> 235 209
# max distance= 235
# distance= 235
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# switching angle -161.39040468314127 -0.4738574903222582 -0.15955901373940284 <built-in function min> 217 193
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# switching angle -125.41033227453293 -0.2897140783597723 -0.40751165971067344 <built-in function min> 235 209
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# switching angle -107.41023460813103 -0.14960562057655866 -0.47709344817541016 <built-in function min> 217 200
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# max distance= 193
# distance= 193
# max distance= 185
# distance= 185
# switching angle -125.4097497016411 -0.2897099348415913 -0.4075146054487874 <built-in function min> 209 185
# max distance= 185
# distance= 185
# max distance= 178
# distance= 178
# max distance= 178
# distance= 178
# switching angle -143.4185351103329 -0.40150515557661365 -0.2979825666803333 <built-in function min> 226 178
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# switching angle -125.41847419756449 -0.2897719842122807 -0.407470486251063 <built-in function min> 235 209
# max distance= 200
# distance= 200
# switching angle -162.28375677890187 -0.4762876251506756 -0.15215156301638685 <built-in function min> 235 200
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 226
# distance= 226
# max distance= 226
# distance= 226
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 217
# distance= 217
# max distance= 209
# distance= 209
# max distance= 200
# distance= 200
# max distance= 200
# distance= 200
# max distance= 185
# distance= 185
# max distance= 178
# distance= 178
# switching angle -144.28376702456185 -0.40595908303266076 -0.291885633259469 <built-in function min> 235 178
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# max distance= 235
# distance= 235
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1a5655f6f5cf> in <module>()
#      13 #         png = cv2.imdecode(rawImage, cv2.IMREAD_UNCHANGED)
#      14 #         gray = cv2.cvtColor(png, cv2.COLOR_BGR2GRAY)
# ---> 15         gray = getScreenDepthVis()
#      16         # slice the image so we only check what we are headed into (and not what is down on the ground below us).
#      17         top = np.vstack((np.vsplit(gray, 3)[0],np.vsplit(gray, 3)[1]))
#
# <ipython-input-2-01f06ccb1cda> in getScreenDepthVis()
#       3 def getScreenDepthVis():
#       4
# ----> 5     responses = client.simGetImages([airsim.ImageRequest(0, airsim.ImageType.DepthPerspective, True, False)])
#       6     img1d = np.array(responses[0].image_data_float, dtype=np.float)
#       7     img1d = 255/np.maximum(np.ones(img1d.size), img1d)
#
# D:\jupyter_dir\Airsim\PythonClient\airsim\client.py in simGetImages(self, requests, vehicle_name)
#     105     # image_type uses one of the ImageType members
#     106     def simGetImages(self, requests, vehicle_name = ''):
# --> 107         responses_raw = self.client.call('simGetImages', requests, vehicle_name)
#     108         return [ImageResponse.from_msgpack(response_raw) for response_raw in responses_raw]
#     109
#
# ~\AppData\Roaming\Python\Python36\site-packages\msgpackrpc\session.py in call(self, method, *args)
#      39
#      40     def call(self, method, *args):
# ---> 41         return self.send_request(method, args).get()
#      42
#      43     def call_async(self, method, *args):
#
# ~\AppData\Roaming\Python\Python36\site-packages\msgpackrpc\future.py in get(self)
#      23
#      24     def get(self):
# ---> 25         self.join()
#      26
#      27         assert self._set_flag == True
#
# ~\AppData\Roaming\Python\Python36\site-packages\msgpackrpc\future.py in join(self)
#      20     def join(self):
#      21         while (not self._set_flag):
# ---> 22             self._loop.start()
#      23
#      24     def get(self):
#
# ~\AppData\Roaming\Python\Python36\site-packages\msgpackrpc\loop.py in start(self)
#      20         """
#      21
# ---> 22         self._ioloop.start()
#      23
#      24     def stop(self):
#
# ~\AppData\Roaming\Python\Python36\site-packages\tornado\ioloop.py in start(self)
#     861
#     862                 try:
# --> 863                     event_pairs = self._impl.poll(poll_timeout)
#     864                 except Exception as e:
#     865                     # Depending on python version and IOLoop implementation,
#
# ~\AppData\Roaming\Python\Python36\site-packages\tornado\platform\select.py in poll(self, timeout)
#      61     def poll(self, timeout):
#      62         readable, writeable, errors = select.select(
# ---> 63             self.read_fds, self.write_fds, self.error_fds, timeout)
#      64         events = {}
#      65         for fd in readable:
#
# KeyboardInterrupt:

# %%
bands

# %%
rawImage = np.fromstring(result, np.int8)
